# %% [markdown]
# ### 비디오 게임 데이터셋 분석

# %% [markdown]
# ### Amazon video games reviews: ㅡㅡ
#  * 이 데이터셋은 Amazon에서 판매하는 비디오 게임 제품에 대한 리뷰와 별점 데이터를 포함하고 있습니다.

# %%
import pandas as pd
import os 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.listdir()
# Out:
# ['.config', '.ipynb_checkpoints', 'All Appliances.csv', 'sample_data']

# %%
# 데이터 불러오기
df = pd.read_csv('All Appliances.csv')

# %%
### 데이터 탐색
# [].head()
# [].tail()
# [].info()
# [].describe()
# [].isnull().sum()
# [].columns
# [].shape

# %%
df.head()
# Out:
#                                                 name main_category  \
# 0  Pigeon by Stovekraft Amaze Plus Electric Kettl...    appliances
# 1  Pigeon Polypropylene Mini Handy and Compact Ch...    appliances
# 2  Glun Multipurpose Portable Electronic Digital ...    appliances
# 3  beatXP Kitchen Scale Multipurpose Portable Ele...    appliances
# 4  Bajaj DX-6 1000W Dry Iron with Advance Solepla...    appliances
#
#      sub_category                                              image  \
# 0  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 2  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 3  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 4  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                 link ratings no_of_ratings  \
# ...

# %%
#각 제품별 링크,별점,가격,할인가격 등이 있다.

# %%
df.tail()
# Out:
#                                                    name main_category  \
# 9571  Kaizen Swimming Pool Heavy Duty In-Ground Pool...    appliances
# 9572  Butterfly 750 Watts 4 Jar Mixer Grinder and 90...    appliances
# 9573     Bajaj Bahar 150 mm Exhaust Fan (Metallic Grey)    appliances
# 9574  Drumstone Barbeque Grill Grilling Set Machine ...    appliances
# 9575  Haier 8.5 Kg Semi-Automatic Top Loading Washin...    appliances
#
#         sub_category                                              image  \
# 9571  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 9572  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 9573  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 9574  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 9575  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                    link ratings no_of_ratings  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            9576 non-null   object
#  1   main_category   9576 non-null   object
#  2   sub_category    9576 non-null   object
#  3   image           9576 non-null   object
#  4   link            9576 non-null   object
#  5   ratings         9098 non-null   object
#  6   no_of_ratings   9098 non-null   object
#  7   discount_price  9214 non-null   object
#  8   actual_price    9485 non-null   object
# dtypes: object(9)
# memory usage: 673.4+ KB

# %%
df.isnull().sum()
# Out:
# name                0
# main_category       0
# sub_category        0
# image               0
# link                0
# ratings           478
# no_of_ratings     478
# discount_price    362
# actual_price       91
# dtype: int64

# %%
df.describe()
# Out:
#                                                      name main_category  \
# count                                                9576          9576
# unique                                               8595             1
# top     Activated Carbon Faucet Water Filters Universa...    appliances
# freq                                                    6          9576
#
#           sub_category                                              image  \
# count             9576                                               9576
# unique               1                                               8853
# top     All Appliances  https://m.media-amazon.com/images/I/41w-je6e5b...
# freq              9576                                                  7
#
#                                                      link ratings  \
# count                                                9576    9098
# unique                                               9576      42
# ...

# %%
df.isnull().sum()
# Out:
# name                0
# main_category       0
# sub_category        0
# image               0
# link                0
# ratings           478
# no_of_ratings     478
# discount_price    362
# actual_price       91
# dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'main_category', 'sub_category', 'image', 'link', 'ratings',
#        'no_of_ratings', 'discount_price', 'actual_price'],
#       dtype='object')

# %%
df.shape
# Out:
# (9576, 9)

# %%
# 데이터 불러오기
# df = pd.read_csv('All Appliances.csv')
df.head()
# Out:
#                                                 name main_category  \
# 0  Pigeon by Stovekraft Amaze Plus Electric Kettl...    appliances
# 1  Pigeon Polypropylene Mini Handy and Compact Ch...    appliances
# 2  Glun Multipurpose Portable Electronic Digital ...    appliances
# 3  beatXP Kitchen Scale Multipurpose Portable Ele...    appliances
# 4  Bajaj DX-6 1000W Dry Iron with Advance Solepla...    appliances
#
#      sub_category                                              image  \
# 0  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 2  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 3  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
# 4  All Appliances  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                 link ratings no_of_ratings  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            9576 non-null   object
#  1   main_category   9576 non-null   object
#  2   sub_category    9576 non-null   object
#  3   image           9576 non-null   object
#  4   link            9576 non-null   object
#  5   ratings         9098 non-null   object
#  6   no_of_ratings   9098 non-null   object
#  7   discount_price  9214 non-null   object
#  8   actual_price    9485 non-null   object
# dtypes: object(9)
# memory usage: 673.4+ KB

# %%
# 제품평점 4.8 이상인 제품 이름 얻기  
# 데이터프레임에서 ratings와 name 컬럼만 추출
df = df[['ratings', 'name']]
df
# Out:
#      ratings                                               name
# 0        NaN  Pigeon by Stovekraft Amaze Plus Electric Kettl...
# 1        NaN  Pigeon Polypropylene Mini Handy and Compact Ch...
# 2        NaN  Glun Multipurpose Portable Electronic Digital ...
# 3        NaN  beatXP Kitchen Scale Multipurpose Portable Ele...
# 4        NaN  Bajaj DX-6 1000W Dry Iron with Advance Solepla...
# ...      ...                                                ...
# 9571     NaN  Kaizen Swimming Pool Heavy Duty In-Ground Pool...
# 9572     NaN  Butterfly 750 Watts 4 Jar Mixer Grinder and 90...
# 9573     NaN     Bajaj Bahar 150 mm Exhaust Fan (Metallic Grey)
# 9574     NaN  Drumstone Barbeque Grill Grilling Set Machine ...
# 9575     NaN  Haier 8.5 Kg Semi-Automatic Top Loading Washin...
#
# [9576 rows x 2 columns]

# %%
# ratings 컬럼에서 , 제거 후 데이터 타입을 float으로 변환
df['ratings']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 9571    NaN
# 9572    NaN
# 9573    NaN
# 9574    NaN
# 9575    NaN
# Name: ratings, Length: 9576, dtype: object

# %%
df['ratings'] = df['ratings'].replace(['nan', 'FREE', 'Get'], np.nan)
df['ratings'] = df['ratings'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-4c4c4cbfe8ab> in <cell line: 2>()
#       1 df['ratings'] = df['ratings'].replace(['nan'], np.nan)
# ----> 2 df['ratings'] = df['ratings'].astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
df.qeu
# Out:
# array([3.9, 4.1, 3.8, 3.7, 4.2, 4.3, 4. , 3.2, 2.6, 4.4, 3.6, 4.5, 2.9,
#        3.4, 4.6, 4.7, 4.9, 3.5, 3.1, 1.7, 2.2, nan, 5. , 3. , 4.8, 1.6,
#        3.3, 1.9, 2.5, 2.8, 2.7, 1. , 2.3, 2. , 2.4, 1.8, 1.4, 2.1, 1.2,
#        1.3, 1.5])

# %%
df['ratings'].unique()
# Out:
# array([nan,
#        'Wooflix Sticky Pet Hair Remover Lint Roller Eco-Friendly Reusable Sticky Lint Roller - Effectively Removes Lint, Hair, Dus...',
#        'PASHV ENTERPRISE Sewing Machine Electric Handheld Sewing Machine Mini Handy Stitch Portable Needlework Cordless Handmade D...',
#        'BlendLife Ultra 600ml Portable Waterproof Blender For Juices, Shakes, Smoothies. 230Watt & 4000MAH Battery. Pulse Mode Fea...',
#        'Rewup Table fan Powerful Rechargeable Table Fan with LED Light, Table Fan for Home, Table Fans, Table Fan for Office Desk,...',
#        'Samsung 236 L 2 Star Inverter Frost-Free Double Door Refrigerator (RT28C3032GS/HL, Gray Silver)',
#        'TASMAX mini waffle maker machine 3 in 1 waffle iron home appliances kitchen gift Easy to Clean, Non-Stick Surfaces, 4 Inc...',
#        'Cascade Mini Portable Air Cooler,Personal Space Cooler Easy to fill water and mood led light and portable Air Conditioner ...',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ratings  468 non-null    object
#  1   name     9576 non-null   object
# dtypes: object(2)
# memory usage: 149.8+ KB

# %%
df.head()
# Out:
#   ratings                                               name
# 0     NaN  Pigeon by Stovekraft Amaze Plus Electric Kettl...
# 1     NaN  Pigeon Polypropylene Mini Handy and Compact Ch...
# 2     NaN  Glun Multipurpose Portable Electronic Digital ...
# 3     NaN  beatXP Kitchen Scale Multipurpose Portable Ele...
# 4     NaN  Bajaj DX-6 1000W Dry Iron with Advance Solepla...
